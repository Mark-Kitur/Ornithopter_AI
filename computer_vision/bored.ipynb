# %%
print('Mark')
# Out:
# Mark

# %%
import pandas as pd
import numpy as np
import os ,glob
from PIL import Image

# %%
'/media/mark/New Volume2/ras/drive/train_h/_annotations.csv'

# %%
house_df= pd.read_csv(r'/media/mark/New Volume2/ras/drive/train_h/_annotations.csv')
many =pd.read_csv(r"/media/mark/New Volume2/ras/drive/train_f/_annotations.csv")
many.head()
# Out:
#                                             filename  width  height  \
# 0  Batch2-IMG0014_JPG.rf.22a7ec70682749e8a8d226fa...   1280     960
# 1  Batch2-IMG0014_JPG.rf.22a7ec70682749e8a8d226fa...   1280     960
# 2  Batch2-IMG0014_JPG.rf.22a7ec70682749e8a8d226fa...   1280     960
# 3  Batch2-IMG0014_JPG.rf.22a7ec70682749e8a8d226fa...   1280     960
# 4  Batch2-IMG0014_JPG.rf.22a7ec70682749e8a8d226fa...   1280     960
#
#        class  xmin  ymin  xmax  ymax
# 0  harvester   276   114  1280   860
# 1       post   133   543   150   676
# 2       post    58   550    93   780
# 3       post   316   606   372   954
# 4       post   379   671   483   956

# %%
start='/media/mark/New Volume2/ras/drive/train_h/'

fn=[]
for  i in house_df['filename']:
    i=start+i
    fn.append(i)
house_df['filename']=fn

start='/media/mark/New Volume2/ras/drive/train_f/'

fne=[]
for  i in many['filename']:
    i=start+i
    fne.append(i)

many['filename']=fne

# %%
Image.open(many['filename'].iloc[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960>

# %%
len(house_df)
# Out:
# 40

# %%
wanted=['person','tractor','post','trunk']
wanted[0]= many[many['class'] == wanted[0]]
wanted[1]= many[many['class'] == wanted[1]]
wanted[2]= many[many['class'] == wanted[2]]
wanted[3]= many[many['class'] == wanted[3]]
wanted[0]=wanted[0][:100]
wanted[1]=wanted[1][:100]
wanted[2]=wanted[2][:100]
wanted[3]=wanted[3][:100]

# %%
quelea = pd.read_csv(r"/media/mark/New Volume2/ras/obejct_detection/computer_vision/data.csv")
quelea= quelea[quelea['class'] =='quelea']
quelea
# Out:
#                                                filename  width  height  \
# 1     E:/ras/Red-billed-quelea-8/select/253_png.rf.9...    640     640
# 3     E:/ras/Red-billed-quelea-8/select/339_jpg.rf.a...    640     640
# 4     E:/ras/Red-billed-quelea-8/select/232_jpg.rf.f...    640     640
# 7     E:/ras/Red-billed-quelea-8/select/284_jpg.rf.e...    640     640
# 12    E:/ras/Red-billed-quelea-8/select/242_jpg.rf.5...    640     640
# ...                                                 ...    ...     ...
# 3821  E:/ras/Red-billed-quelea-8/select/1000_F_74784...    640     640
# 3824  E:/ras/Red-billed-quelea-8/select/263_jpg.rf.8...    640     640
# 3827  E:/ras/Red-billed-quelea-8/select/271_jpg.rf.c...    640     640
# 3833  E:/ras/Red-billed-quelea-8/select/261_jpg.rf.0...    640     640
# 3836  E:/ras/Red-billed-quelea-8/select/red-billed-q...    640     640
#
#        class       x       y    xmax    ymax  b_width  b_height  label
# ...

# %%
quelea['filename'][3][6:]
# Out:
# '/Red-billed-quelea-8/select/339_jpg.rf.adb3294cc029bebe1fdb6605f68b5ae9.jpg'

# %%
start ='/media/mark/New Volume2/ras'
fn=[]
for  i in quelea['filename']:
    i=start+i[6:]
    fn.append(i)
quelea['filename']=fn

# %%
quelea
# Out:
#                                                filename  width  height  \
# 1     /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 3     /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 4     /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 7     /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 12    /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# ...                                                 ...    ...     ...
# 3821  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 3824  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 3827  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 3833  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 3836  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
#
#        class       x       y    xmax    ymax  b_width  b_height  label
# ...

# %%
quelea=quelea[:200]

# %%
quelea.iloc[13]
# Out:
# filename    /media/mark/New Volume2/ras/Red-billed-quelea-...
# width                                                     640
# height                                                    640
# class                                                  quelea
# x                                                       368.9
# y                                                      290.14
# xmax                                                   564.29
# ymax                                                   553.32
# b_width                                                 195.4
# b_height                                                263.2
# label                                                       1
# Name: 70, dtype: object

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread(quelea['filename'].iloc[13])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.rectangle(img,(int(quelea['x'].iloc[13]),int(quelea['y'].iloc[13])), (int(quelea['xmax'].iloc[13]),int(quelea['ymax'].iloc[13])),(0,255,255),2)
plt.imshow(img)
plt.axis('off')
# Out:
# /home/mark/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %%
quelea.rename(columns={'x':'xmin', 'y':'ymin'},inplace=True)
# Out:
# /tmp/ipykernel_5383/1730599703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quelea.rename(columns={'x':'xmin', 'y':'ymin'},inplace=True)

# %%
quelea.drop(['b_width','b_height','label'],axis=1,inplace=True)
quelea.head()
# Out:
# /tmp/ipykernel_5383/2128822353.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quelea.drop(['b_width','b_height','label'],axis=1,inplace=True)
#                                              filename  width  height   class  \
# 1   /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640  quelea
# 3   /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640  quelea
# 4   /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640  quelea
# 7   /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640  quelea
# 12  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640  quelea
#
#       xmin    ymin    xmax    ymax
# 1   183.38  354.94  239.30  436.59
# 3   301.56  199.08  527.05  427.27
# 4    57.77   77.71  181.48  269.21
# ...

# %%
183.38+55.9
# Out:
# 239.28

# %%
data= pd.concat([wanted[0],wanted[1],wanted[2],wanted[3],house_df],ignore_index=True)
data
# Out:
#                                               filename  width  height   class  \
# 0    /media/mark/New Volume2/ras/drive/train_f/ppe_...    800     600  person
# 1    /media/mark/New Volume2/ras/drive/train_f/ppe_...    800     600  person
# 2    /media/mark/New Volume2/ras/drive/train_f/trac...   1280     720  person
# 3    /media/mark/New Volume2/ras/drive/train_f/ppe_...   1376     920  person
# 4    /media/mark/New Volume2/ras/drive/train_f/ppe_...    800     604  person
# ..                                                 ...    ...     ...     ...
# 435  /media/mark/New Volume2/ras/drive/train_h/d76c...   3000    2250  house1
# 436  /media/mark/New Volume2/ras/drive/train_h/b31a...   4608    3456  house1
# 437  /media/mark/New Volume2/ras/drive/train_h/d8eb...    961     640  house1
# 438  /media/mark/New Volume2/ras/drive/train_h/a45f...    800     566  house1
# 439  /media/mark/New Volume2/ras/drive/train_h/c8ee...   1280     897  house1
#
#      xmin  ymin  xmax  ymax
# ...

# %%
data.iloc[130]
# Out:
# filename    /media/mark/New Volume2/ras/drive/train_f/Batc...
# width                                                    2816
# height                                                   1880
# class                                                 tractor
# xmin                                                        0
# ymin                                                      745
# xmax                                                      786
# ymax                                                     1780
# Name: 130, dtype: object

# %%
480/2816 ,480/1880
# Out:
# (0.17045454545454544, 0.2553191489361702)

# %%
img = cv2.imread(data['filename'].iloc[130])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img =cv2.resize(img, (480,480),interpolation=cv2.INTER_AREA)
img = cv2.rectangle(img,(int(data['xmin'].iloc[130]*0.171),int(data['ymin'].iloc[130]*0.255)), (int(data['xmax'].iloc[130]*0.171),int(data['ymax'].iloc[130]*0.255)),(0,255,255),2)
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(479.5), np.float64(479.5), np.float64(-0.5))

# %%
all_data = pd.concat([data,quelea],ignore_index=True)
all_data= all_data.sample(frac=1,ignore_index=True)
all_data
# Out:
#                                               filename  width  height  \
# 0    /media/mark/New Volume2/ras/drive/train_f/Batc...   2048    1536
# 1    /media/mark/New Volume2/ras/drive/train_f/trac...   1280     720
# 2    /media/mark/New Volume2/ras/drive/train_f/IMG0...   3888    2592
# 3    /media/mark/New Volume2/ras/drive/train_f/IMG0...   1280     960
# 4    /media/mark/New Volume2/ras/drive/train_f/Batc...   3888    2592
# ..                                                 ...    ...     ...
# 635  /media/mark/New Volume2/ras/drive/train_f/Batc...   3888    2592
# 636  /media/mark/New Volume2/ras/drive/train_f/ppe_...   1920    1080
# 637  /media/mark/New Volume2/ras/drive/train_f/IMG0...    995    1458
# 638  /media/mark/New Volume2/ras/Red-billed-quelea-...    640     640
# 639  /media/mark/New Volume2/ras/drive/train_f/IMG0...   1280     960
#
#        class     xmin    ymin     xmax     ymax
# 0    tractor   546.00  238.00  1803.00  1173.00
# ...

# %%
labels= all_data['class'].unique()
num_label ={i:v for i,v in enumerate(labels)}
num_label = {v:i for i,v in num_label.items()}
num_label
# Out:
# {'tractor': 0, 'person': 1, 'trunk': 2, 'post': 3, 'quelea': 4, 'house1': 5}

# %%
all_data['labell']= all_data['class'].map(num_label)
all_data.head()
# Out:
#                                             filename  width  height    class  \
# 0  /media/mark/New Volume2/ras/drive/train_f/Batc...   2048    1536  tractor
# 1  /media/mark/New Volume2/ras/drive/train_f/trac...   1280     720   person
# 2  /media/mark/New Volume2/ras/drive/train_f/IMG0...   3888    2592  tractor
# 3  /media/mark/New Volume2/ras/drive/train_f/IMG0...   1280     960    trunk
# 4  /media/mark/New Volume2/ras/drive/train_f/Batc...   3888    2592  tractor
#
#      xmin   ymin    xmax    ymax  labell
# 0   546.0  238.0  1803.0  1173.0       0
# 1   437.0  147.0   501.0   202.0       1
# 2  1347.0    0.0  3077.0  2360.0       0
# 3   228.0  564.0   240.0   614.0       2
# 4     8.0  320.0   498.0  1577.0       0

# %% [markdown]
# # Data Preparation

# %%
import torch
from torch.utils.data import DataLoader,Dataset
import torchvision.transforms as trans
from PIL import Image
import torch.nn as nn

# %%
Image.open(all_data['filename'].iloc[13])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
141/255
# Out:
# 0.5529411764705883

# %%
see=trans.Compose([
    #trans.Resize((480,480)),
    trans.ToTensor()
])
see(img=img).shape
# Out:
# torch.Size([3, 480, 480])

# %%
class PrepareData(Dataset):
    def __init__(self,df):
        self.df =df
        self.transformation = trans.Compose([
            trans.Resize((480,480)),
            trans.ToTensor(),
        ])
        self.num_classes = len(df['class'].unique())
        self.const=480

    def __len__(self):
        return self.df.shape[0]
    
    def __getitem__(self,idx):
        row = self.df.iloc[idx]
        img_pah = row['filename']
        img = Image.open(img_pah).convert('RGB')
        width, height = img.size
        scale_x = self.const/width
        scale_y =self.const/height

        # transformations
        img = self.transformation(img=img)
        xmin,ymin,xmax,ymax= row['xmin']*scale_x,row['ymin']*scale_y, row['xmax']*scale_x,row['ymax']*scale_y

        # convert label to one-hot encoding
        cls = torch.tensor(row['labell'],dtype=torch.long)
        cls = nn.functional.one_hot(cls,num_classes=self.num_classes)

        return {
            'item':img.type(torch.float32),
            'gt':{
                'bbox': torch.Tensor([xmin,ymin,xmax,ymax]).type(torch.float32),
                'cls':cls.type(torch.float32)
            }
        }

# %%
train_data = all_data.sample(frac=0.8, random_state=42).reset_index(drop=True)
val_data = all_data.drop(train_data.index).reset_index(drop=True)
train_dataset=PrepareData(train_data)
val_dataset = PrepareData(val_data)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,num_workers=os.cpu_count())
val_loader = DataLoader(val_dataset,batch_size=batch_size,shuffle=False,num_workers=os.cpu_count())

for batch in train_loader:
    cls = batch['gt']['cls']
    bbox = batch['gt']['bbox']
    images =batch['item']
    print(f'Image shape :{images.shape}')
    print(f'bbox shape :{bbox.shape}')
    print(f'class shape :{cls.shape}')

    break
# Out:
# Image shape :torch.Size([32, 3, 480, 480])
# bbox shape :torch.Size([32, 4])
# class shape :torch.Size([32, 6])
